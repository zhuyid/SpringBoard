# %%
import pandas as pd

# %%
disney = pd.read_csv('DisneyMoviesDataset.csv')

# %%
disney = disney.drop(disney.iloc[:,14:32], axis = 1)
disney = disney.drop(columns = ["Unnamed: 0","Production company","Running time","Release date","Country","Language"])

# %%
disney
# Out:
#                                title  Running time (int)  Budget (float)  \
# 0            Academy Award Review of                41.0             NaN
# 1    Snow White and the Seven Dwarfs                83.0       1490000.0
# 2                          Pinocchio                88.0       2600000.0
# 3                           Fantasia               126.0       2280000.0
# 4               The Reluctant Dragon                74.0        600000.0
# ..                               ...                 ...             ...
# 427                             Soul                 NaN     150000000.0
# 428         Raya and the Last Dragon                 NaN             NaN
# 429                          Cruella                 NaN     200000000.0
# 430                    Jungle Cruise                 NaN             NaN
# 431            The Beatles: Get Back                 NaN             NaN
#
#      Box office (float) Release date (datetime)  imdb  metascore  \
# ...

# %%
disney.columns = ["title","running_time","budget","box_office","release_date","imdb","metascore","rotten_tomatoes"]

# %%
disney
# Out:
#                                title  running_time       budget   box_office  \
# 0            Academy Award Review of          41.0          NaN          NaN
# 1    Snow White and the Seven Dwarfs          83.0    1490000.0  418000000.0
# 2                          Pinocchio          88.0    2600000.0  164000000.0
# 3                           Fantasia         126.0    2280000.0   83300000.0
# 4               The Reluctant Dragon          74.0     600000.0     960000.0
# ..                               ...           ...          ...          ...
# 427                             Soul           NaN  150000000.0          NaN
# 428         Raya and the Last Dragon           NaN          NaN          NaN
# 429                          Cruella           NaN  200000000.0  233500000.0
# 430                    Jungle Cruise           NaN          NaN          NaN
# 431            The Beatles: Get Back           NaN          NaN          NaN
#
# ...

# %%
disney.to_csv('disney.csv')
